# %% [markdown]
# <a href="https://colab.research.google.com/github/shuklaprajwal08-glitch/Python/blob/main/1_Python_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operators

# %% [markdown]
# Q1: Calculate the sum of a and b where a =10 and b = 5.

# %%
a=10
b=5
a+b
# Out:
# 15

# %% [markdown]
# Q2: Find the remainder when 17 is divided by 3.

# %%
17%3
# Out:
# 2

# %% [markdown]
# Q3: Check if X is greater than Y where X = 25 and Y = 20.

# %%
X=25
Y=20
X<Y
# Out:
# False

# %% [markdown]
# Q4: Check if p is equal to q where p = 'hello' and q = 'world'.

# %%
p='hello'
q='world'
p==q
# Out:
# False

# %% [markdown]
# Q5: Evaluate (True and False).

# %%
(True and False)
# Out:
# False

# %%
(True and True)
# Out:
# True

# %%
(False and True)
# Out:
# False

# %%
(False and False)
# Out:
# False

# %% [markdown]
# Q6: Evaluate (True or False).

# %%
(True or False)
# Out:
# True

# %%
(True or True)
# Out:
# True

# %%
(False or True)
# Out:
# True

# %%
(False or False)
# Out:
# False

# %% [markdown]
# Q7: Assign the value 10 to num and 5 to num using an assignment operator.

# %%
num = 10
num += 5
(num)
# Out:
# 15

# %% [markdown]
# Q8: Check if the number 5 is present in the list [1, 2, 3, 4, 5].

# %%
a = [1,2,3,4,5,]
if 5 in a:
  ("5 is present")
else:
  ("5 is not present")
