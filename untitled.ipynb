# %% [markdown]
# <a href="https://colab.research.google.com/github/shuklaprajwal08-glitch/Python/blob/main/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Check whether 15 is greater than 10

# %%
15>=10
# Out:
# True

# %% [markdown]
# 2. Check whether 5 is less than 20

# %%
20>=5
# Out:
# True

# %% [markdown]
# 3. Check whether 10 is equal to 10

# %%
10==10
# Out:
# True

# %% [markdown]
# Check whether 25 is not equal 30

# %%
25==30
# Out:
# False

# %% [markdown]
# Check whether 50 is greater than or equal to 40

# %%
50>=40
# Out:
# True

# %% [markdown]
# check whether 30 is less than or equal to 30

# %%
30>=30
# Out:
# True

# %% [markdown]
# create a variable age = 20 and check whether the age is greater than or equal to 18

# %%
age = 20
age = 18
20>=18
# Out:
# True

# %% [markdown]
# create a variable marks = 35 and check whether marks are greater than or equal to 40.

# %%
marks = 35
marks = 40
40>=35
# Out:
# True

# %% [markdown]
# create two variables:

# %%
a = 10
b = 20

# %% [markdown]
# check whether a is less than b.

# %%
a < b
# Out:
# True

# %% [markdown]
# create:11

# %%
x = 50

# %% [markdown]
# check whether x is equal to 50.

# %%
x == 50
# Out:
# True

# %% [markdown]
# create two variables: num1 = 100 and num2 = 50 .check whether num1 is greater than num2.

# %%
num1 = 100
num2 = 50
num1>num2
# Out:
# True

# %% [markdown]
# check whether the string 'apple' is equal to the string'apple'.

# %%
'apple' == 'apple'
# Out:
# True

# %% [markdown]
# create a variable current_temp = 20. check whether current_temp is not equal to 25.

# %%
current_temp = 20
20 != 25
# Out:
# True

# %% [markdown]
# check whether 7 is less than or equal to 7.

# %%
7<=7
# Out:
# True

# %% [markdown]
# create a variable score = 95.check whether score is greater than 90.

# %%
score = 95
95>=90
# Out:
# True

# %% [markdown]
# create a variable is_raining = True.
# check where is_raining is equal to False.

# %%
is_raining =True
is_raining == False
# Out:
# False

# %% [markdown]
# create a variable item_count = 0. check wheater item_conut is less than 1.

# %%
item_count = 0
0 < 1
# Out:
# True

# %% [markdown]
# create a variable price = 20.50. check whether price is greater than or equals to 20.

# %%
price = 20.50
20.50 > 20
# Out:
# True

# %% [markdown]
# create two string variable : city1= 'London' and city2= 'Paris'. check whether city1 is not equals to city2.

# %%
city1 = 'London'
city2= 'Paris'
'London' != 'Paris'
# Out:
# True

# %% [markdown]
# create a variable year = 2024. check whether year is equal to 2024.

# %%
year = 2024
year == 2024
# Out:
# True
