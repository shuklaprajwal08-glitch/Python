# %% [markdown]
# <a href="https://colab.research.google.com/github/shuklaprajwal08-glitch/Python/blob/main/3_list%26loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Lists — Beginner Lab
#
# ## Learning Objective
# Welcome to your first Python Lists lab! In this lab, you will learn how to store multiple items in a single variable.
#
# You will learn how to:
# * Create and print lists
# * Access elements using positive and negative indexes
# * Change list elements
# * Add elements using `append()` and `insert()`
# * Remove elements using `remove()` and `pop()`
# * Find length using `len()` and check elements using `in`
# * Join, repeat, and slice lists
# * Use `sort()`, `reverse()`, and `clear()`
# * Use `for` loops to go through a list

# %% [markdown]
# ## 1. Creating and Printing Lists
#
# A list is used to store many items in one variable. We use square brackets `[]` to make a list, and we separate items with commas.
#
# ### Example:
# ```python
# numbers = [10, 20, 30, 40, 50]
# print(numbers)
# ```

# %% [markdown]
# ### Q1. Create a list containing 5 numbers of your choice and print it.

# %%
numbers = [7, 10, 29, 18, 45]
print(numbers)
# Out:
# [7, 10, 29, 18, 45]

# %% [markdown]
# ### Q2. Create a list containing 5 student names (strings like "Rahul", "Anjali") and print it.

# %%
 name = ["rajkumar", "rinku", "santosh", "abhinav", "abhiraj"]
 print(name)
# Out:
# ['rajkumar', 'rinku', 'santosh', 'abhinav', 'abhiraj']

# %% [markdown]
# ### Q3. Create a list containing 5 different fruits and print it.

# %%
fruits = ["banana","grapes","mango","kiwi","apple"]
print(fruits)
# Out:
# ['banana', 'grapes', 'mango', 'kiwi', 'apple']

# %% [markdown]
# ### Q4. Create a completely empty list named `empty_list` and print it.

# %%
a=[]
print(a)
# Out:
# []

# %% [markdown]
# ## 2. List Index (Accessing Elements)
#
# Each item in a list has a position number called an **index**. Python starts counting positions from `0`.
#
# ```text
# List:   [10, 20, 30, 40, 50]
# Index:    0   1   2   3   4
# ```
#
# ### Example:
# ```python
# marks = [90, 85, 78]
# print(marks[0]) # Prints the first item: 90
# ```

# %% [markdown]
# ### Q5. Given the list `fruits = ["Apple", "Banana", "Cherry", "Orange"]`, print the first element ("Apple") using its index.

# %%
fruits = ["Apple", "Banana", "Cherry", "Orange"]
print(fruits[0])
# Out:
# Apple

# %% [markdown]
# ### Q6. Given the same `fruits` list, print the third element ("Cherry") using its index.

# %%
fruits = ["Apple", "Banana", "Cherry", "Orange"]
print(fruits[2])
# Out:
# Cherry

# %% [markdown]
# ## 3. Negative Indexing
#
# Negative indexing means starting from the end of the list. `-1` refers to the last item, `-2` refers to the second-last item, and so on.
#
# ```text
# List:            [10, 20, 30, 40, 50]
# Negative Index:  -5  -4  -3  -2  -1
# ```
#
# ### Example:
# ```python
# names = ["Amit", "Priya", "Vijay"]
# print(names[-1]) # Prints "Vijay"
# ```

# %% [markdown]
# ### Q7. Given the list `subjects = ["Maths", "Physics", "Chemistry", "English"]`, print the last element using negative index `-1`.

# %%
subjects = ["Maths", "Physics", "Chemistry", "English"]
print(subjects[-1])
# Out:
# English

# %% [markdown]
# ### Q8. Given the same `subjects` list, print the second-to-last element using negative index `-2`.

# %%
subjects = ["Maths", "Physics", "Chemistry", "English"]
print(subjects[-2])
# Out:
# Chemistry

# %% [markdown]
# ## 4. Changing List Elements
#
# You can change the value of a specific element by using its index and assigning a new value.
#
# ### Example:
# ```python
# colors = ["Red", "Blue", "Green"]
# colors[1] = "Yellow" # Changes "Blue" to "Yellow"
# print(colors)
# ```

# %% [markdown]
# ### Q9. Create a list of 3 cities: `["Delhi", "Mumbai", "Kolkata"]`. Change the first city "Delhi" to "Chennai" and print the modified list.

# %%
cities = ["Delhi", "Mumbai", "Kolkata"]
cities[0] = "Chennai"
print(cities)
# Out:
# ['Chennai', 'Mumbai', 'Kolkata']

# %% [markdown]
# ### Q10. Create a list of numbers: `[100, 200, 300]`. Change the last number `300` to `500` using index `2` and print the modified list.

# %%
numbers = [100, 200, 300]
numbers[2] = 500
print(numbers)
# Out:
# [100, 200, 500]

# %% [markdown]
# ## 5. Adding Elements with `append()`
#
# The `append()` method adds an element to the very end of an existing list.
#
# ### Example:
# ```python
# animals = ["Cat", "Dog"]
# animals.append("Cow")
# print(animals) # ["Cat", "Dog", "Cow"]
# ```

# %% [markdown]
# ### Q11. Create a list named `colors` with `["Red", "Green"]`. Append "Blue" to this list and print it.

# %%
colors = ["Red", "Green"]
colors.append("Blue")
print(colors)
# Out:
# ['Red', 'Green', 'Blue']

# %% [markdown]
# ### Q12. Create an empty list named `scores`. Append the number `10` to it, then append the number `20` to it, and print the list.

# %%
scores = []
scores.append(10)
scores.append(20)
print(scores)
# Out:
# [10, 20]

# %% [markdown]
# ## 6. Adding Elements with `insert()`
#
# The `insert()` method adds an element at a specific index. It takes two arguments: `insert(index, value)`.
#
# ### Example:
# ```python
# numbers = [10, 30, 40]
# numbers.insert(1, 20) # Inserts 20 at index 1
# print(numbers) # [10, 20, 30, 40]
# ```

# %% [markdown]
# ### Q13. Given the list `fruits = ["Apple", "Cherry"]`, insert "Banana" at index `1` so it is in the middle, then print the list.

# %%
fruits = ["Apple", "Cherry"]
fruits.insert(1, "Banana")
print(fruits)
# Out:
# ['Apple', 'Banana', 'Cherry']

# %% [markdown]
# ### Q14. Given the list `marks = [80, 90]`, insert the value `70` at index `0` (the beginning of the list), then print the list.

# %%
marks = [80, 90]
marks.insert(0, 70)
print(marks)
# Out:
# [70, 80, 90]

# %% [markdown]
# ## 7. Removing Elements with `remove()`
#
# The `remove()` method removes the first occurrence of a specific value from the list.
#
# ### Example:
# ```python
# names = ["Amit", "Rahul", "Amit"]
# names.remove("Amit") # Removes only the first "Amit"
# print(names) # ["Rahul", "Amit"]
# ```

# %% [markdown]
# ### Q15. Given the list `languages = ["HTML", "Python", "C++", "Java"]`, remove "HTML" using `.remove()` and print the list.

# %%
languages = ["HTML", "Python", "C++", "Java"]
languages.remove("HTML")
print(languages)
# Out:
# ['Python', 'C++', 'Java']

# %% [markdown]
# ### Q16. Given the list `prices = [10, 20, 30, 40]`, remove the value `30` and print the list.

# %%
prices = [10, 20, 30, 40]
prices.remove(30)
print(prices)
# Out:
# [10, 20, 40]

# %% [markdown]
# ## 8. Removing Elements with `pop()`
#
# * `list.pop()` removes and returns the last element of the list.
# * `list.pop(index)` removes the element at that specific index.
#
# ### Example:
# ```python
# letters = ["A", "B", "C"]
# letters.pop() # Removes "C"
# print(letters) # ["A", "B"]
# ```

# %% [markdown]
# ### Q17. Given the list `students = ["Rohan", "Sita", "Gita"]`, use `.pop()` with no arguments to remove the last element, then print the list.

# %%
students = ["Rohan", "Sita", "Gita"]
students.pop()
print(students)
# Out:
# ['Rohan', 'Sita']

# %% [markdown]
# ### Q18. Given the list `items = ["Pen", "Pencil", "Eraser", "Ruler"]`, use `.pop(1)` to remove the item at index 1 ("Pencil"), then print the list.

# %%
items = ["Pen", "Pencil", "Eraser", "Ruler"]
items.pop(1)
print(items)
# Out:
# ['Pen', 'Eraser', 'Ruler']

# %% [markdown]
# ## 9. Finding Length with `len()` and Checking with `in`
#
# * `len(list)` returns the total number of items in a list.
# * `value in list` returns `True` if the item is present, otherwise `False`.
#
# ### Example:
# ```python
# items = ["Books", "Pens"]
# print(len(items)) # Prints 2
# print("Pens" in items) # Prints True
# ```

# %% [markdown]
# ### Q19. Create a list containing 6 of your favorite foods. Use `len()` to print the length of your list.

# %%
foods = ["Pizza", "Burger", "Pasta", "Salad", "Sushi", "Tacos"]
print(len(foods))
# Out:
# 6

# %% [markdown]
# ### Q20. Given the list `cities = ["Mumbai", "Pune", "Bangalore"]`, check if "Pune" is in the list using the `in` keyword and print the result (it should display `True`).

# %%
cities = ["Mumbai", "Pune", "Bangalore"]
print("Pune" in cities)
# Out:
# True

# %% [markdown]
# ## 10. Joining (`+`) and Repeating (`*`) Lists
#
# * Use the `+` operator to merge or join two lists together.
# * Use the `*` operator to repeat a list a certain number of times.
#
# ### Example:
# ```python
# a = [1, 2]
# b = [3, 4]
# print(a + b) # [1, 2, 3, 4]
# print(a * 3) # [1, 2, 1, 2, 1, 2]
# ```

# %% [markdown]
# ### Q21. Create two lists: `list1 = [1, 2, 3]` and `list2 = [4, 5, 6]`. Join them using `+` and print the combined list.

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combined_list = list1 + list2
print(combined_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Q22. Create a list `items = ["Hello"]`. Use the `*` operator to repeat it 5 times and print the resulting list.

# %%
items = ["Hello"]
repeated_list = items * 5
print(repeated_list)
# Out:
# ['Hello', 'Hello', 'Hello', 'Hello', 'Hello']

# %% [markdown]
# ## 11. Slicing a List
#
# Slicing allows you to get a part of a list using `list[start:stop]`. Note that the `stop` index is **not** included.
#
# ### Example:
# ```python
# numbers = [10, 20, 30, 40, 50]
# print(numbers[1:4]) # Gets items from index 1 to 3: [20, 30, 40]
# ```

# %% [markdown]
# ### Q23. Given the list `numbers = [10, 20, 30, 40, 50, 60]`, slice and print the first 3 elements (`[10, 20, 30]`).

# %%
numbers = [10, 20, 30, 40, 50, 60]
print(numbers[0:3])
# Out:
# [10, 20, 30]

# %% [markdown]
# ### Q24. Given the same `numbers` list, slice and print the elements from index 2 to index 4 (`[30, 40, 50]`).

# %%
numbers = [10, 20, 30, 40, 50, 60]
print(numbers[2:5])
# Out:
# [30, 40, 50]

# %% [markdown]
# ## 12. `sort()`, `reverse()`, and `clear()`
#
# * `sort()` arranges a list in ascending order.
# * `reverse()` reverses the order of the elements in-place.
# * `clear()` deletes all elements from the list, leaving it empty.
#
# ### Example:
# ```python
# vals = [3, 1, 2]
# vals.sort()
# print(vals) # [1, 2, 3]
# ```

# %% [markdown]
# ### Q25. Given the list `unsorted_marks = [45, 92, 12, 56, 78]`, sort it in ascending order using `.sort()` and print the list.

# %%
unsorted_marks = [45, 92, 12, 56, 78]
unsorted_marks.sort()
print(unsorted_marks)
# Out:
# [12, 45, 56, 78, 92]

# %% [markdown]
# ### Q26. Given the list `letters = ["a", "b", "c", "d"]`, reverse its order using `.reverse()` and print the list.

# %%
letters = ["a", "b", "c", "d"]
letters.reverse()
print(letters)
# Out:
# ['d', 'c', 'b', 'a']

# %% [markdown]
# ### Q27. Given the list `temp_list = [5, 10, 15]`, clear all of its elements using `.clear()` and print the resulting empty list.

# %%
temp_list = [5, 10, 15]
temp_list.clear()
print(temp_list)
# Out:
# []

# %% [markdown]
# ### Q28. Create a list of 3 names. Create a copy of this list in a new variable using `.copy()`, and print the copied list.

# %%
names = ["Alice", "Bob", "Charlie"]
copied_names = names.copy()
print(copied_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# ## 13. `for` Loop with Lists
#
# You can easily look at every item in a list one by one using a standard `for` loop.
#
# ### Example:
# ```python
# fruits = ["Apple", "Banana"]
# for fruit in fruits:
#     print(fruit)
# ```

# %% [markdown]
# ### Q29. Create a list containing 4 different subjects. Use a `for` loop to print each subject on a new line.

# %%
subjects = ["Math", "Science", "English", "History"]
for subject in subjects:
    print(subject)
# Out:
# Math
# Science
# English
# History

# %% [markdown]
# ### Q30. Create a list containing the numbers `[1, 2, 3, 4, 5]`. Use a `for` loop to multiply each number by `2` and print the result.

# %%
numbers = [1, 2, 3, 4, 5]
for numbers in numbers:
    result = numbers * 2
    print(result)
# Out:
# 2
# 4
# 6
# 8
# 10
